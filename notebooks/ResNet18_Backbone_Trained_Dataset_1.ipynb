# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'chest-x-ray-images:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F4610581%2F7859946%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240525%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240525T112655Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,resnet18-model:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F4628445%2F7884876%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240525%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240525T112655Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading chest-x-ray-images, 765806673 bytes compressed
# [==================================================] 765806673 bytes downloaded
# Downloaded and uncompressed: chest-x-ray-images
# Downloading resnet18-model, 43451679 bytes compressed
# [==================================================] 43451679 bytes downloaded
# Downloaded and uncompressed: resnet18-model
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/resnet18-model/resnet18-f37072fd.pth
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900572.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900643.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNQnsTXsAE8zqD.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900675.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-bilateral.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/053.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900171.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900661.png
# /kaggle/input/chest-x-ray-images/CXR Images/case48_Xray_4.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/88de9d8c39e946abd495b37cd07d89e5-6531-0.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900578.png
# /kaggle/input/chest-x-ray-images/CXR Images/ryct.2020200034.fig5-day0.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/case8_xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/CASE25_XRAY_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900696.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900502.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900154.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00027.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNT6a4X0AE38he.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNO9IkXgAAazUZ.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/figure1-5e75d0940b71e1b702629659-98-right.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900399.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNXXzTWoAA9oNk.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900412.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00008.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900410.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00020.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900625.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900395.png
# /kaggle/input/chest-x-ray-images/CXR Images/1-s2.0-S0929664620300449-gr2_lrg-a.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/6CB4EFC6-68FA-4CD5-940C-BEFA8DAFE9A7.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900352.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900287.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900601.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00018.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900415.png
# /kaggle/input/chest-x-ray-images/CXR Images/025.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNQCewXYAAOxkU.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/CASE60_XRAY_2.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/027.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid190084.png
# /kaggle/input/chest-x-ray-images/CXR Images/CASE30_XRAY_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/23E99E2E-447C-46E5-8EB2-D35D12473C39.png
# /kaggle/input/chest-x-ray-images/CXR Images/case46_Xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900523.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900156.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-19.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-20-pa-on-admission.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900558.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900642.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900576.png
# /kaggle/input/chest-x-ray-images/CXR Images/kjr-21-e24-g002-l-a.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid19004.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNLaa6XkAA4k5p.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid190030.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900424.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900200.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00003a.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900456.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900541.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00038.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNPho1WsAg4eE6.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900542.png
# /kaggle/input/chest-x-ray-images/CXR Images/049.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-001-fig2a.png
# /kaggle/input/chest-x-ray-images/CXR Images/nejmoa2001191_f1-PA.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid190078.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900512.png
# /kaggle/input/chest-x-ray-images/CXR Images/1-s2.0-S0929664620300449-gr2_lrg-b.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/CASE65_XRAY_2.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900348.png
# /kaggle/input/chest-x-ray-images/CXR Images/079.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNVaHHXYAIkYgM.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNNfv2XYAAtYQo.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/radiol.2020200274.fig3d.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00006.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNUghfXkAM7VHk.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNUiJ0WAAE9I2Q.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900622.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900339.png
# /kaggle/input/chest-x-ray-images/CXR Images/4e43e48d52c9e2d4c6c1fb9bc1544f_jumbo.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/CASE57_XRAY_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/CASE22_XRAY_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900307.png
# /kaggle/input/chest-x-ray-images/CXR Images/076.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/026.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNWpWGWoAMgXxO.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900283.png
# /kaggle/input/chest-x-ray-images/CXR Images/figure1-5e71be566aa8714a04de3386-98-left.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNW5rCXYAAC9bf.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/056.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900547.png
# /kaggle/input/chest-x-ray-images/CXR Images/41591_2020_819_Fig1_HTML.webp-day5.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900571.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900507.png
# /kaggle/input/chest-x-ray-images/CXR Images/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-000-fig1b.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNSJVAXsAADTXF.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900240.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-infection-exclusive-gastrointestinal-symptoms-pa.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNQqWYX0AA_CHh.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/case7_xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00003b.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/kjr-21-e25-g001-l-a.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/nejmc2001573_f1a.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900303.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900302.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900275.png
# /kaggle/input/chest-x-ray-images/CXR Images/extubation-8.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid190047.png
# /kaggle/input/chest-x-ray-images/CXR Images/58cb9263f16e94305c730685358e4e_jumbo.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/094.png
# /kaggle/input/chest-x-ray-images/CXR Images/all14238-fig-0001-m-c.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/073.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00010.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNN3psWAAASg3p.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/case47_Xray_3.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNTHE_XkAAtmiY.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900695.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900388.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900334.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNL8znX0AA_dzC.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNQEglXkAM0MA0.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00035.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNPrNHWoAA4e2Z.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900161.png
# /kaggle/input/chest-x-ray-images/CXR Images/yxppt-2020-02-19_00-51-27_287214-day8.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNWPaTWAAEhWhl.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EURyFBbXYAAp3GU.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900551.png
# /kaggle/input/chest-x-ray-images/CXR Images/062.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/069.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900166.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00007.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-34.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900263.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900195.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900127.png
# /kaggle/input/chest-x-ray-images/CXR Images/01.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNPuoiWoAAW435.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900367.png
# /kaggle/input/chest-x-ray-images/CXR Images/039.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/078.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/16660_2_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNJkQbWsAAJhw-.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900404.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid190063.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900268.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNYQzRWsAIhJg2.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid190068.png
# /kaggle/input/chest-x-ray-images/CXR Images/nejmc2001573_f1b.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid190026.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900373.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900608.png
# /kaggle/input/chest-x-ray-images/CXR Images/31BA3780-2323-493F-8AED-62081B9C383B.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900444.png
# /kaggle/input/chest-x-ray-images/CXR Images/ryct.2020200034.fig5-day7.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900593.png
# /kaggle/input/chest-x-ray-images/CXR Images/auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus (2).jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/case70_xray_3.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/08.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900418.png
# /kaggle/input/chest-x-ray-images/CXR Images/AR-1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900155.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900313.png
# /kaggle/input/chest-x-ray-images/CXR Images/1-s2.0-S1684118220300682-main.pdf-003-b2.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900612.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900654.png
# /kaggle/input/chest-x-ray-images/CXR Images/015.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/010.png
# /kaggle/input/chest-x-ray-images/CXR Images/case44_Xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid190040.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900256.png
# /kaggle/input/chest-x-ray-images/CXR Images/7-fatal-covid19.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/gr1_lrg-b.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900584.png
# /kaggle/input/chest-x-ray-images/CXR Images/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-002-fig3a.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900385.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900420.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNLZGfWsAMl1t1.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-58-day-7.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900555.png
# /kaggle/input/chest-x-ray-images/CXR Images/1312A392-67A3-4EBF-9319-810CF6DA5EF6.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/046.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00014.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/040.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNVlT9X0AAJyqS.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/0119.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900515.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900179.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNNiDVXkAYP1W-.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900294.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNO4YLXQAMnLsT.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/090.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid190036.png
# /kaggle/input/chest-x-ray-images/CXR Images/16672_1_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/021.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EURyHSzXgAE4O-n.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid190054.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00016.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-evolution-over-a-week-1-day0-PA.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/E63574A7-4188-4C8D-8D17-9D67A18A1AFA.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNTIOHXkAEr5tE.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/098.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900686.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900381.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNQ_O5WkAEkfoN.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/02.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900324.png
# /kaggle/input/chest-x-ray-images/CXR Images/2966893D-5DDF-4B68-9E2B-4979D5956C8E.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/085.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/084.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/gr1_lrg-a.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EURzk-YXsAERAsI.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNU62aXQAIUo_F.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900172.png
# /kaggle/input/chest-x-ray-images/CXR Images/FE9F9A5D-2830-46F9-851B-1FF4534959BE.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900202.png
# /kaggle/input/chest-x-ray-images/CXR Images/083.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00030.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-15-PA.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/067.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900432.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900132.png
# /kaggle/input/chest-x-ray-images/CXR Images/auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus (2).jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900349.png
# /kaggle/input/chest-x-ray-images/CXR Images/radiol.2020200490.fig3.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNK7bZWsAAOiRf.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/055.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/06.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900241.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid190043.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900531.png
# /kaggle/input/chest-x-ray-images/CXR Images/ryct.2020200028.fig1a.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900595.png
# /kaggle/input/chest-x-ray-images/CXR Images/16660_3_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900344.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900598.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNU8D_WAAA6Kon.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/case42_Xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00013a.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/F4341CE7-73C9-45C6-99C8-8567A5484B63.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/045.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/38_A.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/052.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900309.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00025.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNLptKWkAEwbk4.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900442.png
# /kaggle/input/chest-x-ray-images/CXR Images/kjr-21-e24-g003-l-a.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-12.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/6C94A287-C059-46A0-8600-AFB95F4727B7.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNWmR3XsAARmxa.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/CASE59_XRAY_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/CASE66_XRAY_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/071.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900697.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNTZLxWoAAtKn5.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00001.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900239.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNVtm2X0AEXFs1.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900567.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-38-pa.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/0112.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/case8_xray_2.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/CASE63_XRAY_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/065.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNYaU8XQAAvS0z.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNVH9LWoAI9DVJ.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNW3p_WAAETF-h.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNVJLXXsAAc2bH.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/CASE64_XRAY_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900544.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900449.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900149.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900345.png
# /kaggle/input/chest-x-ray-images/CXR Images/7AF6C1AF-D249-4BD2-8C26-449304105D03.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900106.png
# /kaggle/input/chest-x-ray-images/CXR Images/16654_2_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/auntminnie-2020_01_31_20_24_2322_2020_01_31_x-ray_coronavirus_US.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00029.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/1B734A89-A1BF-49A8-A1D3-66FAFA4FAC5D.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/031.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid190042.png
# /kaggle/input/chest-x-ray-images/CXR Images/16660_4_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900151.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900574.png
# /kaggle/input/chest-x-ray-images/CXR Images/extubation-1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/059.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNK-sHWoAAttJB.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00005.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900437.png
# /kaggle/input/chest-x-ray-images/CXR Images/03.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNT7qdWoAAJDkc.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNQpLCWkAA8EeI.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/CASE24_XRAY_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900483.png
# /kaggle/input/chest-x-ray-images/CXR Images/080.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900450.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00011.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900107.png
# /kaggle/input/chest-x-ray-images/CXR Images/032.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/F2DE909F-E19C-4900-92F5-8F435B031AC6.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNNhF6WkAAwedM.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900119.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNK9aGXgAAjyz-.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/case40_Xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/024.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNN1FeWkAUvcPK.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNPInyXkAIvcOX.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/04.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNJ81ZXYAIpXGC.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900300.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900384.png
# /kaggle/input/chest-x-ray-images/CXR Images/ciaa199.pdf-001-b.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900655.png
# /kaggle/input/chest-x-ray-images/CXR Images/047.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900464.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900644.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900258.png
# /kaggle/input/chest-x-ray-images/CXR Images/radiopaedia-2019-novel-coronavirus-infected-pneumonia.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900709.png
# /kaggle/input/chest-x-ray-images/CXR Images/CASE60_XRAY_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNT_GzXsAAxpdg.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/case43_Xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNQb-bXQAEvKWx.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900691.png
# /kaggle/input/chest-x-ray-images/CXR Images/case48_Xray_5.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/0105.png
# /kaggle/input/chest-x-ray-images/CXR Images/1-s2.0-S1684118220300682-main.pdf-003-b1.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900244.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900394.png
# /kaggle/input/chest-x-ray-images/CXR Images/061.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900561.png
# /kaggle/input/chest-x-ray-images/CXR Images/089.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900702.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00024.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNV3ZZWkAAo3wq.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900370.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid190075.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900117.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00036.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid190045.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-20.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900346.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900457.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900638.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNM3uLX0AALWoL.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/nejmoa2001191_f5-PA.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/nejmoa2001191_f4.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/case38_Xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-001-fig2b.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNQY7LXQAAk6N6.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUR2CTsWoAAo4O9.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/054.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNOYrWXYAEWy3r.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900660.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNRQsxWAAM_rOW.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/ae6c954c0039de4b5edee53865ffee43-e6c8-0.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/1-s2.0-S0929664620300449-gr2_lrg-d.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900269.png
# /kaggle/input/chest-x-ray-images/CXR Images/auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus (2).jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-30-PA.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/CASE56_XRAY_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900167.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNWVT7X0AA3MzP.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900174.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900336.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNTcLTXYAEzvUG.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/064.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNW4xcWsAE8G4S.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900315.png
# /kaggle/input/chest-x-ray-images/CXR Images/012.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900150.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900189.png
# /kaggle/input/chest-x-ray-images/CXR Images/case14_xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/086.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900569.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900700.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900301.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900318.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900333.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00012 (2).jpg
# /kaggle/input/chest-x-ray-images/CXR Images/case68_xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00003b (2).jpg
# /kaggle/input/chest-x-ray-images/CXR Images/8FDE8DBA-CFBD-4B4C-B1A4-6F36A93B7E87.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900364.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNP_R3XgAMivfJ.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/2C26F453-AF3B-4517-BB9E-802CF2179543.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00019.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid19003.png
# /kaggle/input/chest-x-ray-images/CXR Images/022.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNQrxvWsAElFV0.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900402.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900260.png
# /kaggle/input/chest-x-ray-images/CXR Images/0106.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/091.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900492.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900108.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNYTfgXkAEUybN.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNJ6ZsXkAYcyW8.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/AR-2.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EURzhIvXsAY5tyz.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/03BF7561-A9BA-4C3C-B8A0-D3E585F73F3C.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900246.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNL_1FXkAEloX3.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900249.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-35-2.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900347.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00013b.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNYKqDXYAIcyty.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900590.png
# /kaggle/input/chest-x-ray-images/CXR Images/060.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900252.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNNeTSXYAMAVE8.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900266.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00028.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/case70_xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/1-s2.0-S1684118220300682-main.pdf-002-a1.png
# /kaggle/input/chest-x-ray-images/CXR Images/1-s2.0-S1684118220300682-main.pdf-002-a2.png
# /kaggle/input/chest-x-ray-images/CXR Images/020.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900549.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900433.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNVUpwWoAAoaFw.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/case34_Xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900498.png
# /kaggle/input/chest-x-ray-images/CXR Images/ciaa199.pdf-001-c.png
# /kaggle/input/chest-x-ray-images/CXR Images/case44_Xray_2.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EURyGCJWAAEbSwa.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNKfK4XYAsZEGJ.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/CASE58_XRAY_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNW6wFWAAAgk0W.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/096.png
# /kaggle/input/chest-x-ray-images/CXR Images/088.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/0113.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNRp5aX0AE3btZ.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900118.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900210.png
# /kaggle/input/chest-x-ray-images/CXR Images/068.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNPvyQWAAEICd1.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/051.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900509.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900175.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00034.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/lancet-case2b.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNKdRwX0AkSuqk.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/0120.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/CASE29_XRAY_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00033 (2).jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900548.png
# /kaggle/input/chest-x-ray-images/CXR Images/042.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900653.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900342.png
# /kaggle/input/chest-x-ray-images/CXR Images/1-s2.0-S1684118220300608-main.pdf-001.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/1-s2.0-S0929664620300449-gr2_lrg-c.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900164.png
# /kaggle/input/chest-x-ray-images/CXR Images/CASE23_XRAY_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/CD50BA96-6982-4C80-AE7B-5F67ACDBFA56.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/CASE61_XRAY_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00012.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/CASE21_XRAY_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNKhePXkAcPjIs.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/041.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900286.png
# /kaggle/input/chest-x-ray-images/CXR Images/kjr-21-e24-g001-l-a.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/072.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00009.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/043.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900317.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00026.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00037 (2).jpg
# /kaggle/input/chest-x-ray-images/CXR Images/ryct.2020200034.fig2.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNWoZ8X0AIBvCM.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/case41_Xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/0118.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNR30nXkAYYWYN.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900137.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900242.png
# /kaggle/input/chest-x-ray-images/CXR Images/88de9d8c39e946abd495b37cd07d89e5-2ee6-0.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900277.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNYaU8XsAE16Y1.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid190074.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid190066.png
# /kaggle/input/chest-x-ray-images/CXR Images/case47_Xray_2.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/6b44464d-73a7-4cf3-bbb6-ffe7168300e3.annot.original.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900389.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900458.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-58-day-3.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00033.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900563.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900272.png
# /kaggle/input/chest-x-ray-images/CXR Images/044.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00021.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00017.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid190083.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-14-PA.png
# /kaggle/input/chest-x-ray-images/CXR Images/nCoV-radiol.2020200269.fig1-day7.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-003-fig4a.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900398.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900659.png
# /kaggle/input/chest-x-ray-images/CXR Images/CASE26_XRAY_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900614.png
# /kaggle/input/chest-x-ray-images/CXR Images/9C34AF49-E589-44D5-92D3-168B3B04E4A6.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900163.png
# /kaggle/input/chest-x-ray-images/CXR Images/ciaa199.pdf-001-a.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900580.png
# /kaggle/input/chest-x-ray-images/CXR Images/057.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/53EC07C9-5CC6-4BE4-9B6F-D7B0D72AAA7E.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNT86fWsAE3k1u.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900475.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900708.png
# /kaggle/input/chest-x-ray-images/CXR Images/1-s2.0-S1684118220300608-main.pdf-002.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00022 (2).jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-53.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/nejmoa2001191_f3-PA.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900533.png
# /kaggle/input/chest-x-ray-images/CXR Images/paving.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNO77QXYAA8MPb.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900508.png
# /kaggle/input/chest-x-ray-images/CXR Images/fff49165-b22d-4bb4-b9d1-d5d62c52436c.annot.original.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNVLFTWkAExRZS.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNL-rAXkAUdgDs.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/16654_1_1.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-28.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNO5pTWsAE0rw_.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNRORPXgAEm4oe.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/074.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900356.png
# /kaggle/input/chest-x-ray-images/CXR Images/EURzjweWAAAGOO9.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/353889E0-A1E8-4F9E-A0B8-F24F36BCFBFB.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/all14238-fig-0001-m-b.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900698.png
# /kaggle/input/chest-x-ray-images/CXR Images/extubation-4.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/case48_Xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNOXdOXYAARIWj.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/16660_1_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-caso-70-1-PA.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/0108.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/41591_2020_819_Fig1_HTML.webp-day10.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNXDMHX0AEioiZ.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNVKIjWoAAwF9b.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-44-day-0.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900215.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00015a.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900611.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNJ-OBXgAEV_1y.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900617.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00037.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900470.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900221.png
# /kaggle/input/chest-x-ray-images/CXR Images/CASE54_XRAY_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/09.png
# /kaggle/input/chest-x-ray-images/CXR Images/0111.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900413.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900673.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUR1DIHXYAIpOqi.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-7-PA.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/058.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900657.png
# /kaggle/input/chest-x-ray-images/CXR Images/16669_3_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-58-day-9.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/1-s2.0-S0140673620303706-fx1_lrg.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus (2).jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900596.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900602.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-2.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900329.png
# /kaggle/input/chest-x-ray-images/CXR Images/092.png
# /kaggle/input/chest-x-ray-images/CXR Images/case47_Xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-35-1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900467.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid190055.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900623.png
# /kaggle/input/chest-x-ray-images/CXR Images/033.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900594.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00022.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00004.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/7C69C012-7479-493F-8722-ABC29C60A2DD.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900343.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900299.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900409.png
# /kaggle/input/chest-x-ray-images/CXR Images/80446565-E090-4187-A031-9D3CEAA586C8.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900435.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900308.png
# /kaggle/input/chest-x-ray-images/CXR Images/extubation-13.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900416.png
# /kaggle/input/chest-x-ray-images/CXR Images/0102.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/B2D20576-00B7-4519-A415-72DE29C90C34.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNN2g1XgAMzICz.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/CASE67_XRAY_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900629.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNQ4TDXkAAxvth.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUR2DcOXgAEg1Xt.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EURzicIWkAEQV0B.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUR1EeAWkAEZPqh.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/case4_xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/case50_Xray_1.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00002.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/050.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/CASE55_XRAY_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/case48_Xray_3.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900289.png
# /kaggle/input/chest-x-ray-images/CXR Images/081.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/lancet-case2a.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNXXzOXsAEaQrp.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900645.png
# /kaggle/input/chest-x-ray-images/CXR Images/CASE31_XRAY_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/082.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNJ_q6WsAALXas.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/16691_1_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900607.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNWBoVXYAMNmRi.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900429.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900505.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid190059.png
# /kaggle/input/chest-x-ray-images/CXR Images/EURz8m_WoAAZle7.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900322.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid-19-pneumonia-67.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900187.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900170.png
# /kaggle/input/chest-x-ray-images/CXR Images/CASE27_XRAY_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNMA6SWAAMHods.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900229.png
# /kaggle/input/chest-x-ray-images/CXR Images/case13_xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900147.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00032.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNK5-hXgAE_LZq.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900491.png
# /kaggle/input/chest-x-ray-images/CXR Images/F63AB6CE-1968-4154-A70F-913AF154F53D.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/048.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/01E392EE-69F9-4E33-BFCE-E5C968654078.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNQAlZXsAEfH0_.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/case2_xray_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-002-fig3b.png
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00023.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/9fdd3c3032296fd04d2cad5d9070d4_jumbo.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/CASE32_XRAY_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/case48_Xray_2.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00031.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/0115.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNTay6XkAAobzP.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNRcbKXQAAAThb.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/16654_4_1.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid190087.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNXfwIWsAEHSIL.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/93FE0BB1-022D-4F24-9727-987A07975FFB.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/case34_Xray_3.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900582.png
# /kaggle/input/chest-x-ray-images/CXR Images/6b3bdbc31f65230b8cdcc3cef5f8ba8a-40ac-0.jpg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900630.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNWUd3XYAAd7s1.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/EUNMSP9XgAUp2gT.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/COVID-00015b.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900145.png
# /kaggle/input/chest-x-ray-images/CXR Images/0100.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-000-fig1a.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNM6J0XsAEEAl9.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/019.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900314.png
# /kaggle/input/chest-x-ray-images/CXR Images/85E52EB3-56E9-4D67-82DA-DEA247C82886.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/EUNRrxJXsAIrgas.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/ryct.2020200034.fig5-day4.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900196.png
# /kaggle/input/chest-x-ray-images/CXR Images/1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-003-fig4b.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNUa7YXgAEu4hn.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900377.png
# /kaggle/input/chest-x-ray-images/CXR Images/EUNU6cSXgAATX_h.jfif
# /kaggle/input/chest-x-ray-images/CXR Images/covid19005.png
# /kaggle/input/chest-x-ray-images/CXR Images/covid1900165.png
# /kaggle/input/chest-x-ray-images/CXR Images/07.jpg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0073-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0807-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0521-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0587-0001-0002.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/053.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0535-0001-0002.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0555-0001-0002.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0375-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0125-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0421-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0930-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0723-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0207-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0396-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/066.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0511-0001-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0456-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/0114.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0971-0001-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0306-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0707-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/064.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/025.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0117-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0449-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0425-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0455-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0886-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0906-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0790-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0389-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0264-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0500-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0683-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0332-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0388-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0137-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0576-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0692-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0414-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0887-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0618-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0480-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0623-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0487-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0453-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0089-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0912-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0187-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0523-0001-0003.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0037-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0326-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0588-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0803-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/013.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0439-0001-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0840-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/NORMAL2-IM-0536-0001.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/079.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Normal/IM-0016-0001.jpeg
# ...
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person384_virus_769.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person50_virus_102.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person119_virus_225.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1180_virus_2014.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1206_virus_2051.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person410_virus_821.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1397_virus_2400.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1350_virus_2329.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person502_virus_1011.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person124_virus_233.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person393_virus_784.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person600_virus_1156.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1665_virus_2878.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person604_virus_1165.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1342_virus_2315.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person692_virus_1286.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1331_virus_2299.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person736_virus_1358.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1285_virus_2208.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person442_virus_904.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person588_virus_1135.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1324_virus_2285.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1418_virus_2429.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/075.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person400_virus_794.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1200_virus_2042.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person706_virus_1304.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/063.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person484_virus_986.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person445_virus_912.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person624_virus_1198.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person935_virus_1597.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/0108.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person37_virus_82.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person734_virus_1355.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1343_virus_2316.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/011.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/016.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1368_virus_2352.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/0105.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1395_virus_2398.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1180_virus_2011.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person573_virus_1116.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person106_virus_194.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person402_virus_799.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person445_virus_916.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1328_virus_2294.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person964_virus_1637.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1362_virus_2345.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person623_virus_1197.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person110_virus_206.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person778_virus_1408.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person348_virus_714.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person515_virus_1032.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person442_virus_902.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person401_virus_798.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person17_virus_48.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/061.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person765_virus_1393.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person488_virus_992.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person407_virus_812.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/037.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/058.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1656_virus_2862.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1679_virus_2896.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person38_virus_83.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person419_virus_859.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1643_virus_2843.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person111_virus_209.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person430_virus_879.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1441_virus_2457.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1448_virus_2468.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/071.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1_virus_13.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person399_virus_793.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person441_virus_895.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person124_virus_236.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person461_virus_949.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person327_virus_679.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person575_virus_1119.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person16_virus_47.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1387_virus_2382.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/034.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1359_virus_2340.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person432_virus_881.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1310_virus_2255.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1647_virus_2848.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person434_virus_883.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person124_virus_231.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person414_virus_845.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person490_virus_996.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person447_virus_921_1.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/020.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person633_virus_1213.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person124_virus_245.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person954_virus_1626.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/09.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person451_virus_932.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person419_virus_861.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1193_virus_2034.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person18_virus_49.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person557_virus_1097.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person71_virus_131.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/0102.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1296_virus_2224.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person442_virus_898.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person392_virus_782.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1340_virus_2311.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person442_virus_903.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person681_virus_1272.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person407_virus_814.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/095.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person363_virus_742.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1332_virus_2300.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person442_virus_906.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person636_virus_1217.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1_virus_6.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person110_virus_205.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person938_virus_1600.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/081.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person702_virus_1299.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1426_virus_2439.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1662_virus_2875.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1422_virus_2434.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person612_virus_1179.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1363_virus_2346.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person463_virus_953.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person328_virus_681.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person346_virus_709.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1300_virus_2240.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person629_virus_1207.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1244_virus_2111.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person3_virus_17.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1366_virus_2349.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person61_virus_118.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1283_virus_2206.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person476_virus_973.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person379_virus_762.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1357_virus_2338.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person57_virus_113.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1627_virus_2819.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person427_virus_875.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1424_virus_2437.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person947_virus_1618.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person494_virus_1000.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1236_virus_2096.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person330_virus_683.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1358_virus_2339.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/033.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person718_virus_1316.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person3_virus_15.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person672_virus_1261.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/082.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person574_virus_1118.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person962_virus_1635.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/048.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1341_virus_2313.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person942_virus_1611.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1438_virus_2452.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1294_virus_2221.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person460_virus_948.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/035.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person409_virus_820.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person124_virus_239.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1314_virus_2268.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/0116.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/0115.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1233_virus_2090.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person441_virus_897.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person445_virus_918.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person433_virus_882.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person492_virus_998.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1223_virus_2073.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/05.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person577_virus_1121.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person20_virus_51.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person637_virus_1218.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person441_virus_894.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1661_virus_2872.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1316_virus_2271.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person583_virus_1127.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person324_virus_658.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person442_virus_905.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person679_virus_1270.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person120_virus_226.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1365_virus_2348.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person673_virus_1263.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1187_virus_2023.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1248_virus_2117.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1234_virus_2093.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1306_virus_2249.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person509_virus_1024.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person507_virus_1019.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/019.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person639_virus_1220.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1188_virus_2024.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/0113.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1355_virus_2336.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person724_virus_1344.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person445_virus_914.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person516_virus_1033.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1375_virus_2366.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/0120.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person950_virus_1621.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/person1344_virus_2319.jpeg
# /kaggle/input/chest-x-ray-images/CXR Images Pneumonia/0111.jpeg

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
covid_directory = f'/kaggle/input/chest-x-ray-images/CXR Images'
normal_directory = f'/kaggle/input/chest-x-ray-images/CXR Images Normal'
pneumonia_directory = f'/kaggle/input/chest-x-ray-images/CXR Images Pneumonia'

image_size = (224, 224)

def load_images(directory):
    class_images = []
    for filename in os.listdir(directory):
        image_path = os.path.join(directory, filename)
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        resized_image = cv2.resize(image, image_size)
        resized_image = resized_image.astype(np.float32)
        normalized_image = resized_image / 255.0
        class_images.append(normalized_image)

    return np.array(class_images)

covid_images = load_images(covid_directory)
normal_images = load_images(normal_directory)
pneumonia_images = load_images(pneumonia_directory)

print(covid_images.shape)
print(normal_images.shape)
print(pneumonia_images.shape)
# Out:
# (673, 224, 224, 3)
# (758, 224, 224, 3)
# (709, 224, 224, 3)

# %%
fig, ax = plt.subplots(ncols=3, figsize = (20,20))
ax[0].imshow(covid_images[0])
ax[0].title.set_text("Covid 19")
ax[1].imshow(normal_images[0])
ax[1].title.set_text("Normal")
ax[2].imshow(pneumonia_images[0])
ax[2].title.set_text("Pneumonia")

# %%
all_images = np.concatenate((covid_images, normal_images, pneumonia_images), axis=0)
print(all_images.shape)
covid_labels = np.zeros(len(covid_images), dtype=np.int32)
pneumonia_labels = np.ones(len(pneumonia_images), dtype=np.int32)
normal_labels = np.full(len(normal_images), 2, dtype=np.int32)

all_labels = np.concatenate((covid_labels, normal_labels, pneumonia_labels), axis=0)
print(all_labels.shape)
# Out:
# (2140, 224, 224, 3)
# (2140,)

# %%
train_val_split, test_split = 0.6, 0.4
X_train_val, X_test, y_train_val, y_test = train_test_split(all_images, all_labels, train_size = train_val_split, test_size = test_split, random_state=42, stratify=all_labels)
train_split, val_split = 0.9, 0.1
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, train_size=train_split, test_size=val_split, random_state=42, stratify=y_train_val)

import torch
from torch import nn
from torchvision import models

def create_model():
    model = models.resnet18(weights='DEFAULT')
    for parameter in model.parameters():
        parameter.requires_grad = True

    input_features = model.fc.in_features
    model.fc = nn.Linear(input_features, 3)
    model.fc = nn.Sequential(nn.Dropout(p=0.5), model.fc, nn.Softmax(dim=1))

    return model

model = create_model()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 152MB/s]

# %%
from torch.utils.data import DataLoader, TensorDataset

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)

num_epochs = 5
batch_size= 64


X_train = torch.tensor(X_train)
y_train = torch.tensor(y_train)
X_val = torch.tensor(X_val)
y_val = torch.tensor(y_val)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)
X_train = X_train.to(device)
y_train = y_train.to(device)
X_val = X_val.to(device)
y_val = y_val.to(device)


def calculate_accuracy(outputs, labels):
    _, predicted = torch.max(outputs, 1)
    correct = (predicted == labels).sum().item()
    total = labels.size(0)
    accuracy = correct / total
    return accuracy


train_dataset = torch.utils.data.TensorDataset(X_train, y_train)
validation_dataset = torch.utils.data.TensorDataset(X_val, y_val)

train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
validation_data_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False)


train_acc_list = []


for epoch in range(num_epochs):
    model.train()
    total_loss = 0.0
    total_accuracy = 0.0
    for i, (images, labels) in enumerate(train_data_loader):
        images = images.permute(0, 3, 1, 2)
        optimizer.zero_grad()
        labels = labels.long()
        outputs = model(images)
        num_classes = 3
        one_hot_labels = torch.nn.functional.one_hot(labels, num_classes)
        proper_labels = torch.argmax(one_hot_labels, dim=1)
        loss = criterion(outputs, proper_labels)
        loss.backward()
        optimizer.step()


        total_loss += loss.item()


        accuracy = calculate_accuracy(outputs, proper_labels)
        total_accuracy += accuracy

        if (i + 1) % 10 == 0 or i + 1 == len(train_data_loader):
            avg_loss = total_loss / (i + 1)
            avg_accuracy = total_accuracy / (i + 1)


            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_data_loader)}], "
                  f"Loss: {avg_loss:.4f}, Accuracy: {avg_accuracy:.4f}")


    avg_epoch_loss = total_loss / len(train_data_loader)
    avg_epoch_accuracy = (100 * total_accuracy) / len(train_data_loader)
    train_acc_list.append(avg_epoch_accuracy)
    print(f"Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_epoch_loss:.4f}, "
          f"Average Accuracy: {avg_epoch_accuracy:.4f}")

print("Training complete")
# Out:
# Epoch [1/5], Step [10/19], Loss: 0.6957, Accuracy: 0.8531
# Epoch [1/5], Step [19/19], Loss: 0.6641, Accuracy: 0.8914
# Epoch [1/5], Average Loss: 0.6641, Average Accuracy: 89.1447
# Epoch [2/5], Step [10/19], Loss: 0.6398, Accuracy: 0.9156
# Epoch [2/5], Step [19/19], Loss: 0.6743, Accuracy: 0.8761
# Epoch [2/5], Average Loss: 0.6743, Average Accuracy: 87.6096
# Epoch [3/5], Step [10/19], Loss: 0.6275, Accuracy: 0.9250
# Epoch [3/5], Step [19/19], Loss: 0.6335, Accuracy: 0.9167
# Epoch [3/5], Average Loss: 0.6335, Average Accuracy: 91.6667
# Epoch [4/5], Step [10/19], Loss: 0.6094, Accuracy: 0.9437
# Epoch [4/5], Step [19/19], Loss: 0.6291, Accuracy: 0.9200
# Epoch [4/5], Average Loss: 0.6291, Average Accuracy: 91.9956
# Epoch [5/5], Step [10/19], Loss: 0.6071, Accuracy: 0.9469
# Epoch [5/5], Step [19/19], Loss: 0.6010, Accuracy: 0.9523
# Epoch [5/5], Average Loss: 0.6010, Average Accuracy: 95.2303
# Training complete

# %%
val_accuracy_list = []
model.eval()
with torch.no_grad():
  val_loss = 0.0
  val_correct = 0
  total_samples = 0
  for epoch in range(0, num_epochs):
    for i, (images, labels) in enumerate(validation_data_loader):
      images.to(device)
      labels.to(device)
      images = images.permute(0,3,1,2)
      labels = labels.long()
      outputs = model(images)
      val_loss += criterion(outputs, labels).item() * images.size(0)
      _, predicted = torch.max(outputs.data, 1)
      val_correct += (predicted == labels).sum().item()
      total_samples += labels.shape[0]

    val_accuracy = 100.0 * val_correct / total_samples
    avg_loss = val_loss / total_samples
    val_accuracy_list.append(val_accuracy)
    print(f"Epoch [{epoch+1}/{num_epochs}], Validation Loss: {avg_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%")
# Out:
# Epoch [1/5], Validation Loss: 0.6962, Validation Accuracy: 84.50%
# Epoch [2/5], Validation Loss: 0.6962, Validation Accuracy: 84.50%
# Epoch [3/5], Validation Loss: 0.6962, Validation Accuracy: 84.50%
# Epoch [4/5], Validation Loss: 0.6962, Validation Accuracy: 84.50%
# Epoch [5/5], Validation Loss: 0.6962, Validation Accuracy: 84.50%

# %%
print(train_acc_list)
print(val_accuracy_list)
plt.plot(range(1, len(train_acc_list) + 1), train_acc_list, label='Training Accuracy')
plt.plot(range(1, len(val_accuracy_list) + 1), val_accuracy_list, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [89.14473684210526, 87.60964912280701, 91.66666666666667, 91.99561403508773, 95.23026315789474]
# [84.49612403100775, 84.49612403100775, 84.49612403100775, 84.49612403100775, 84.49612403100775]

# %%
X_test = torch.tensor(X_test)
y_test = torch.tensor(y_test)

test_dataset = torch.utils.data.TensorDataset(X_test, y_test)

test_data_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)


model.eval()
with torch.no_grad():
  test_loss = 0.0
  test_correct = 0
  total_samples = 0
  predicted_labels = []
  true_labels = []
  for i, (images, labels) in enumerate(test_data_loader):
    images = images.to(device)
    labels = labels.to(device)
    images = images.permute(0,3,1,2)
    labels = labels.long()
    outputs = model(images)
    test_loss += criterion(outputs, labels).item() * images.size(0)
    _, predicted = torch.max(outputs.data, 1)
    test_correct += (predicted == labels).sum().item()
    total_samples += labels.shape[0]

    predicted_labels.extend(predicted.cpu().tolist())
    true_labels.extend(labels.cpu().tolist())

  test_accuracy = 100.0 * test_correct / total_samples
  test_loss = test_loss / total_samples

  from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score

  accuracy = accuracy_score(true_labels, predicted_labels)
  precision = precision_score(true_labels, predicted_labels, average='macro')
  recall = recall_score(true_labels, predicted_labels, average='macro')
  f1 = f1_score(true_labels, predicted_labels, average='macro')

  print(f"Testing Loss: {test_loss:.4f}, Testing Accuracy: {test_accuracy:.2f}%")
  print(f"Accuracy Score: {accuracy:.4f}")
  print(f"Macro Precision: {precision:.4f}")
  print(f"Macro Recall: {recall:.4f}")
  print(f"Macro F1-Score: {f1:.4f}")
# Out:
# Testing Loss: 0.6539, Testing Accuracy: 89.72%
# Accuracy Score: 0.8972
# Macro Precision: 0.9223
# Macro Recall: 0.8953
# Macro F1-Score: 0.8994

# %%
micro_precision = precision_score(true_labels, predicted_labels, average='micro')
micro_recall = recall_score(true_labels, predicted_labels, average='micro')
micro_f1 = f1_score(true_labels, predicted_labels, average='micro')


print(f"Micro Precision: {micro_precision:.4f}")
print(f"Micro Recall: {micro_recall:.4f}")
print(f"Micro F1: {micro_f1:.4f}")



from sklearn.metrics import confusion_matrix
class_labels = ['COVID19', 'Pneumonia', 'Normal']

cm = confusion_matrix(true_labels, predicted_labels)
sns.heatmap(cm, annot=True, cbar=True, fmt='d', cmap='YlGnBu', xticklabels = class_labels, yticklabels= class_labels)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Micro Precision: 0.8972
# Micro Recall: 0.8972
# Micro F1: 0.8972

# %%
# !pip install captum

# %%
from google.colab import drive
drive.mount('/content/gdrive')

torch.save(model.state_dict(), '/content/gdrive/MyDrive/Model Checkpoints and metrics/resnet18_complete_saved.pt')
test_metrics = {
  "accuracy": accuracy,
  "Macro precision": precision,
  "Macro recall": recall,
  "Macro f1_score": f1,
  "Micro Precision": micro_precision,
  "Micro Recall": micro_recall,
  "Micro f1_score": micro_f1,
  "confusion_matrix": cm.tolist(),
}

import pickle
with open("/content/gdrive/MyDrive/Model Checkpoints and metrics/resnet_18_complete_test_metrics.pkl", "wb") as f:
  pickle.dump(test_metrics, f)
print("Done!")
